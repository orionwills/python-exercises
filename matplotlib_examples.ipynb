# %% [markdown]
# # matplotlib lesson
# ## how to jupyter

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
x = list(range(150))
x[0:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
plt.plot(x)
plt.show()

# %%
plt.plot(range(len(x)), x)
plt.show()

# %%
plt.plot(x)
plt.xlim(-20, 200)
plt.ylim(-5, 160)
plt.show()

# %%
plt.plot(x, c='red')
plt.show()

# %%
from random import randint

# %%
#some random data
x1 = [randint(-5, 25) + n for n in range(150)]
x2 = [x + randint(-6, 6) for x in x1]

# %%
print(xl)
print('~~~~~~')
print(x2)
# Out:
# [-2, 0, 25, -1, 19, 29, 16, 20, 22, 14, 25, 8, 14, 8, 37, 36, 21, 25, 27, 15, 17, 30, 27, 33, 24, 50, 32, 25, 43, 24, 38, 36, 51, 46, 49, 55, 44, 51, 36, 46, 42, 43, 43, 65, 54, 61, 42, 46, 44, 57, 65, 51, 56, 74, 54, 67, 75, 67, 65, 60, 78, 86, 80, 63, 59, 61, 65, 86, 93, 86, 78, 85, 74, 97, 99, 85, 72, 86, 73, 90, 81, 86, 93, 103, 103, 85, 83, 86, 107, 84, 107, 107, 97, 93, 109, 107, 106, 121, 120, 95, 113, 125, 106, 116, 120, 104, 118, 125, 128, 125, 134, 126, 137, 134, 138, 127, 132, 137, 138, 138, 119, 125, 122, 146, 148, 122, 149, 131, 127, 154, 130, 131, 147, 135, 148, 157, 153, 150, 134, 151, 147, 142, 146, 167, 168, 162, 146, 149, 165, 162]
# ~~~~~~
# [-1, 16, -1, 5, 31, 15, 3, 8, 20, 29, 38, 19, 16, 27, 17, 22, 23, 10, 24, 49, 37, 18, 22, 30, 43, 18, 40, 37, 54, 50, 45, 60, 55, 53, 60, 37, 42, 42, 61, 43, 61, 59, 35, 50, 45, 56, 69, 51, 56, 72, 66, 67, 73, 67, 63, 74, 67, 85, 78, 65, 89, 79, 51, 79, 85, 73, 75, 62, 78, 69, 84, 84, 100, 87, 91, 79, 95, 88, 90, 87, 107, 85, 89, 92, 107, 89, 94, 93, 91, 111, 93, 91, 102, 96, 118, 118, 99, 99, 101, 94, 120, 109, 114, 104, 97, 127, 129, 111, 104, 120, 125, 140, 120, 132, 127, 119, 115, 112, 129, 131, 113, 117, 137, 133, 133, 115, 130, 131, 128, 137, 143, 127, 148, 137, 124, 156, 137, 153, 144, 143, 158, 154, 146, 146, 145, 140, 143, 168, 144, 144]

# %%
plt.plot(x1, c='green', alpha=0.4)
plt.plot(x2, c='red', alpha=.25)
plt.show()

# %%
plt.scatter(range(len(x1)), x1, s=30, c='blue')
plt.scatter(range(len(x2)), x2, s = 10, c='red')
plt.title('Random dots for your face')
plt.xlim(-20, 200)
plt.ylim(-5, 160)
plt.show()

# %%
x = list(range(-49, 50))
y = [n ** 2 for n in x]
plt.scatter(x,y)
plt.title('An exponential Distribution, $y = x^2$')
plt.xlabel('$x$')
plt.ylabel('$x^2$')
plt.show()

# %%
x = [1, 2, 3.14, 4]
y = [n ** 2 for n in x]
plt.scatter(x,y)
plt.xticks([1,2,3.14, 5], ['one', 'two', '$\pi$', 'four'])
plt.show()

# %%
import math
x = range(-4,4)
y = [math.sin(n) for n in x]
plt.scatter(x,y)
plt.plot(x,y,ls='--')
plt.title('An approximation of the sin function')
plt.xlabel('x')
plt.ylabel('\sin(x)')
plt.show()

# %%
x = range(1,5)
y = x
plt.scatter(x,y)
plt.yticks([1,2,3,4], ['one', 'two', 'three', 'four'], rotation=45)
plt.xticks(rotation=90)
plt.show()

# %%
import random
weekdays = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']*3

x = range(14)
y = [random.randint(1,10) for _ in x]
plt.plot(x,y)
plt.xticks(x, weekdays, rotation=60)
plt.show()

# %%
x = list(range(-4,4))
x.append(3.14159)
y = [math.sin(n) for n in x]

plt.scatter(x,y)
plt.plot (x, y, ls=':')

plt.text(.25, 0, '0,0', fontsize=10, color='blue')
plt.text(1.2, .1, '($\pi$, sin($\pi$)', fontsize=14, color='red')

plt.show()

# %%
x = range(-3, 10)
y = [n * 2 for n in x]
z = [n / 2 for n in x]

plt.plot(x, y, c='orange')
plt.plot(x, z, c='green')

plt.annotate('Intersection', xy=(0,0), xytext=(-3, 9), arrowprops={'facecolor': 'blue'})
# Out:
# Text(-3, 9, 'Intersection')

# %%
x = range(-4,5)
sin_x = [math.sin(n) for n in x]
cos_x = [math.cos(n) for n in x]

plt.figure(figsize=(14,6))

plt.scatter(x, sin_x, c='blue')
plt.scatter(x, cos_x, c='orange')
plt.plot(x, sin_x, c='blue', label='$\sin(x)$')
plt.plot(x, cos_x, c='orange', label='$\cos(x)$')

plt.legend(loc='upper right')
plt.title('THICC sin and cosine curves')
plt.xlabel('$x$')

plt.show()

# %% [markdown]
# ## Subplots

# %%
n_rows = 2
n_cols = 2

x = [1,2,3,4,5]
y = [5,4,3,2,1]
z = [1,2,3,4,5]

plt.subplot(n_rows, n_cols, 1)
plt.plot(x,y)
plt.title('x ~ z')

plt.subplot(n_rows, n_cols, 2)
plt.plot(x,z)
plt.title('x ~ z')

plt.subplot(n_rows, n_cols, 3)
plt.plot(x,y)
plt.title('x ~ z')

plt.subplot(n_rows, n_cols, 4)
plt.plot(x,z)
plt.title('x ~ z')

plt.show()

# %%
x = [1,1,2,3,3,3,4,4,5]

plt.hist(x)
plt.show()

# %%
x = [1,1,2,3,3,3,4,4,5]

plt.hist(x, bins=[0,1,2,3,4,5,6])
plt.show()

# %%
x = [1, 1, 2, 3, 3, 3, 4, 4, 5]

plt.figure(figsize=(16, 6))
plt.suptitle(f'x = {x}')

plt.subplot(131)
plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6])
plt.title('align="middle" (default)')

plt.subplot(132)
plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6], align='left')
plt.title('align="left"')

plt.subplot(133)
plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6], align='right')
plt.title('align="right"')

plt.show()

# %%
plt.figure(figsize=(12, 8))
for i in range(1, 5):
    n = 10 ** i
    x1 = [randint(1, 6) for _ in range(n)]
    x2 = [randint(1, 6) for _ in range(n)]

    total = [x + y for x, y in zip(x1, x2)]

    plt.subplot(2, 2, i)
    plt.hist(total, bins=range(2, 14), align='left', color='white', edgecolor='black')
    plt.title(f'n = {n}')

plt.suptitle('Sum of 2 dice rolls')
plt.show()

# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline

n = 1000
x1 = [random.randint(1, 6) for _ in range(n)]
x2 = [random.randint(1, 6) for _ in range(n)]

plt.hist2d(x=x1, y=x2, bins=range(1, 8), )
plt.xlabel('x1')
plt.ylabel('x2')
plt.colorbar()
plt.show()

# %%
x = [n / 100 for n in range(-10000, 10000)]
y = list(x)

plt.plot(x, y)
plt.xscale('linear') # the default
plt.yscale('log')
plt.show()
