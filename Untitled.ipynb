# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from env import user, pw, host
import matplotlib.pyplot as plt
from pydataset import data

# %%
prices= pd.Series(['$796,459.41', '$278.60', '$482,571.67', '$4,503,915.98', '$2,121,418.3', '$1,260,813.3', '$87,231.01', '$1,509,175.45', '$4,138,548.00', '$2,848,913.80',
                   '$594,715.39', '$4,789,988.17', '$4,513,644.5', '$3,191,059.97', '$1,758,712.24', '$4,338,283.54', '$4,738,303.38', '$2,791,759.67', '$769,681.94', '$452,650.23'])

prices = pd.Series(prices).str.replace('$', '').str.replace(',', '')
prices
# Out:
# 0      796459.41
# 1         278.60
# 2      482571.67
# 3     4503915.98
# 4      2121418.3
# 5      1260813.3
# 6       87231.01
# 7     1509175.45
# 8     4138548.00
# 9     2848913.80
# 10     594715.39
# 11    4789988.17
# 12     4513644.5
# 13    3191059.97
# 14    1758712.24
# 15    4338283.54
# 16    4738303.38
# 17    2791759.67
# 18     769681.94
# 19     452650.23
# dtype: object

# %%
cars = data('mpg')

# %%
cars.shape
# Out:
# (234, 11)

# %%
(cars.cty > cars.hwy).any()
# Out:
# False

# %%
cars['mileage_difference'] = cars.hwy - cars.cty
cars
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
cars[['manufacturer', 'hwy', 'cty']].groupby('manufacturer').mean().sort_values(by='hwy', ascending=False)
# Out:
#                     hwy        cty
# manufacturer
# honda         32.555556  24.444444
# volkswagen    29.222222  20.925926
# hyundai       26.857143  18.642857
# audi          26.444444  17.611111
# pontiac       26.400000  17.000000
# subaru        25.571429  19.285714
# toyota        24.911765  18.529412
# nissan        24.615385  18.076923
# chevrolet     21.894737  15.000000
# ford          19.360000  14.000000
# mercury       18.000000  13.250000
# dodge         17.945946  13.135135
# jeep          17.625000  13.500000
# lincoln       17.000000  11.333333
# land rover    16.500000  11.500000
